# %% [markdown]
# This is a minimal notebook that demonstrates the basic structure that you can use for your FP-4 assignment.
#
# The recommended file organization is:
#
# ```
# ./parent_folder/main.ipynb
# ./parent_folder/parse_data.py
# ./parent_folder/descriptive.py
# ./parent_folder/data.csv
# ```
#
# Inside `parse_data.py`:
#
# ```python
# import pandas as pd
#
# def parse_data():
#     df = 'dummy dataframe'
#
#     ### read data
#     # fpath = ''
#     # df = pdf.read_csv( fpath )
#
#     ### process data
#     # ...
#
#     return df
# ```
#
#
# Inside `descriptive.py`:
#
# ```python
# import matplotlib.pyplot as plt
#
# def final_descriptive_plot():
#     plt.figure( figsize=(4,3) )
#     plt.plot( [0,2,5,3,8] )
#     plt.show()
#
# def descriptive( df ):
#     # process dataframe:
#     # ...
#     # report results:
#     final_descriptive_plot()
# ```

# %%
import parse_data as prs

df = prs.parse_data()
print( df )
# Out:
#      price   age         mrt  latitude  longitude
# 0     37.9  32.0    84.87882  24.98298  121.54024
# 1     42.2  19.5   306.59470  24.98034  121.53951
# 2     47.3  13.3   561.98450  24.98746  121.54391
# 3     54.8  13.3   561.98450  24.98746  121.54391
# 4     43.1   5.0   390.56840  24.97937  121.54245
# ..     ...   ...         ...       ...        ...
# 409   15.4  13.7  4082.01500  24.94155  121.50381
# 410   50.0   5.6    90.45606  24.97433  121.54310
# 411   40.6  18.8   390.96960  24.97923  121.53986
# 412   52.5   8.1   104.81010  24.96674  121.54067
# 413   63.9   6.5    90.45606  24.97433  121.54310
#
# [414 rows x 5 columns]

# %%
import descriptive as dsc

dsc.descriptive( df )
# Out:
# <br><br><p><span style="font-size: 1.2em;"><b>Table 1</b>: Central tendency summary statistics.</span></p>
#         price     age       mrt  latitude  longitude
# mean    37.98  17.713  1083.886    24.969    121.533
# median  38.45  16.100   492.231    24.971    121.539
# mode    24.70   0.000   289.325    24.974    121.543
